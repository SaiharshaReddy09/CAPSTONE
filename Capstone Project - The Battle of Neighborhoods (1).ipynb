# %% [markdown]
# # Capstone Project - The Battle of Neighborhoods WEEK2

# %% [markdown]
# ## AIM(Description of Problem):

# %% [markdown]
# Hello!!!! Nowadays everyone needs income to survive,to earn we have to loose something like our lovely home so as to shift to the new place to earn money.This results us to select a new house and different lifestyle,we cant change our fate so why dont we choose a neighborhood which we love.This project focusses on selecting neighborhood based on their interests(like if he's a foodie then more restaurants,so on).Also we will disclose the latitude,longitude positions of various grocery stores,Restaurents,etc to the client for his easy commute to the required place.Intially I thought of using my country INDIA but due to lack of available data I'm selecting our previous week place i.e. Scarborough in toronto.

# %% [markdown]
# ###### Everyone in the world travels and we explore new places.To find for what venue that place is famous for we can use this project.For example by hearing the name INDIA a foodie recalls biryani.But now the place is restricted to Scarborough,Canada

# %% [markdown]
# ## DATA REQUIRED:

# %% [markdown]
# Here I will use the data from wikipedia source which we also used in previous lab which is as follows
# https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M
#
# We also require access to foursquare API as we need the data regarding the neighborhood

# %% [markdown]
# ## METHODOLOGY:

# %% [markdown]
# We will use the skills obtained from previous labs and fetch data from Foursquare API to get the locations of various groceries stores,tourist places,etc in the required neighborhood.

# %% [markdown]
# ## RESULTS:

# %% [markdown]
# By the obtained results we can say that if a person visits Agincourt then he can find more shopping malls and Caledonia-Fairbanks is famous for parks,so on.By seeing the obtained table we can find a lot more about the place.
# Suppose we are new to Agincourt then we can know the popular venue categories are as below:
# [Shopping Mall	,Park	,Pool	,Bubble Tea Shop	,Breakfast Spot	,Latin American Restaurant,	Supermarket,	Sushi Restaurant,	Discount Store,	Chinese Restaurant]

# %% [markdown]
# ## CONCLUSIONS:

# %% [markdown]
# I noticed that there are atleast one park in any area within 600m.The only venues that change are type of restaurants.We can also conclude that places with high frequency in table has more venues than other.

# %% [markdown]
# ## DISCUSSION SECTION:

# %% [markdown]
# Restaurants are quite common in any area,so I guess this project helps to establish a different cuisine restaurannt like indian,latin american,sushi,etc which are not in that area.This attracts a lt of customers

# %% [markdown]
# A link to the notebook I shared on WATSON STUDIO is below:
# https://eu-gb.dataplatform.cloud.ibm.com/analytics/notebooks/v2/1ac47cf3-1988-4fcc-815a-84ab6636077d/view?access_token=13f2f1097ab7f617f0f37b01a7db9825b992ad0660aabdf34db2bd4836c19bca
